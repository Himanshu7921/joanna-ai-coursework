# %% [markdown]
# ## Practical Exercises: Advanced Tensors, Reshaping, and Batch Operations
#
# ### Directions
# 1. Insert a new code cell directly below each question block.
# 2. Write your programmatic solution inside that new cell.
# 3. Commit your changes and submit by pushing to your dedicated Git feature branch.

# %%
# ==============================================================================================
# QUESTION 1: Simple 1D Vector Assembly (Warm-up)
# ----------------------------------------------------------------------------------------------
# Task: Create a 1D NumPy array representing 12 continuous pixel intensity values.
#
# Requirements:
# 1. Initialize a 1D NumPy array named `pixel_strip` containing 12 elements of your choice 
#    integers between 0 and 255.
# 2. Print the array shape using `.shape`.
# 3. Print the data type of the array elements using `.dtype`.
# ==============================================================================================

# Write your solution in a new cell below this one

# %%
# ==============================================================================================
# QUESTION 2: Assembling a Single Grayscale Channel matrix
# ----------------------------------------------------------------------------------------------
# Task: Take a flat vector of numbers and structure it into a 2D matrix representing 
#       a single grayscale image.
#
# Requirements:
# 1. Create a flat 1D array of 16 sequential numbers from 10 to 25 (hint: use np.arange).
# 2. Reshape this array into a 2D matrix named `gray_image` with dimensions 4x4.
# 3. Print the resulting matrix and verify its shape is explicitly (4, 4).
# ==============================================================================================

# Write your solution in a new cell below this one

# %%
# ==============================================================================================
# QUESTION 3: Constructing a Simulated 3D RGB Image Tensor
# ----------------------------------------------------------------------------------------------
# Task: Manually combine separate color matrices to understand how a 3D RGB image tensor is built.
#
# Requirements:
# 1. Create three separate 3x3 matrices filled with identical values using `np.full`:
#    - `red_channel` filled with 1s
#    - `green_channel` filled with 2s
#    - `blue_channel` filled with 3s
# 2. Stack these three matrices along a new axis to create a single 3D tensor named `rgb_tensor` 
#    of shape (3, 3, 3) (hint: look up `np.stack` or write a list of arrays converted to an array).
# 3. Print the tensor shape to verify the arrangement is [Channels, Height, Width].
# ==============================================================================================

# Write your solution in a new cell below this one

# %%
# ==============================================================================================
# QUESTION 4: Grayscale Value Normalization Pipeline
# ----------------------------------------------------------------------------------------------
# Task: Process raw pixel integer values [0, 255] into normalized floating-point scales [0.0, 1.0].
#
# Requirements:
# 1. Create a 5x5 matrix filled with random integers between 0 and 255 (hint: np.random.randint).
# 2. Write an if-else statement check: verify if any pixel value exceeds 255 or falls below 0.
# 3. Divide the entire matrix element-wise by 255.0 to scale the range to [0.0, 1.0].
# 4. Print the maximum and minimum values of the normalized array to verify the new bounds.
# ==============================================================================================

# Write your solution in a new cell below this one

# %%
# ==============================================================================================
# QUESTION 5: Mini Image Conditional Threshold Filter
# ----------------------------------------------------------------------------------------------
# Task: Use control loops and statements to create a binary threshold filter for low-light pixels.
#
# Requirements:
# 1. Given the following raw grayscale patch:
#    pixel_patch = np.array([[50, 180], [30, 220]])
# 2. Initialize a blank copy matrix of the same size filled with zeros.
# 3. Use nested loops (loop over rows, then columns) to inspect each pixel.
# 4. If the pixel value is greater than or equal to 100, set the corresponding position in 
#    your new matrix to 255. Otherwise, keep it at 0.
# 5. Print your final processed binary threshold image matrix.
# ==============================================================================================

# Write your solution in a new cell below this one

# %%
# ==============================================================================================
# QUESTION 6: Reshaping a Single Image Vector for MLP Consumption
# ----------------------------------------------------------------------------------------------
# Task: Take a 3D image tensor and convert it into the precise 2D format an MLP expects.
#
# Requirements:
# 1. Generate a mock random RGB image tensor named `single_input_img` of shape (3, 32, 32).
# 2. An MLP expects an input to include a sample dimension, structured as: (1, Total_Features).
# 3. Use `.reshape()` or `np.reshape()` to flatten the image into a 2D tensor of shape (1, 3072).
# 4. Print the final shape and write a comment explaining where the number 3072 comes from.
# ==============================================================================================

# Write your solution in a new cell below this one

# %%
# ==============================================================================================
# QUESTION 7: Simulating Batch Creation from Independent Images
# ----------------------------------------------------------------------------------------------
# Task: Convert independent 3D image arrays into a single unified 4D batch tensor.
#
# Requirements:
# 1. Generate 4 independent random images named `img_a`, `img_b`, `img_c`, and `img_d`, each 
#    having an RGB shape of (3, 28, 28).
# 2. Group these individual arrays into a single Python list.
# 3. Use `np.array()` to convert that list into a single integrated 4D tensor named `image_batch`.
# 4. Print the shape of `image_batch` and confirm it follows the layout: [N, C, H, W].
# ==============================================================================================

# Write your solution in a new cell below this one

# %%
# ==============================================================================================
# QUESTION 8: Group-Flattening an Entire Batch Matrix
# ----------------------------------------------------------------------------------------------
# Task: Flatten an entire batch of images concurrently while protecting the batch dimension index.
#
# Requirements:
# 1. Create a 4D tensor named `raw_batch` of shape (8, 3, 64, 64) representing 8 RGB images.
# 2. An MLP requires an input batch format of (N, D), where N remains the batch count (8).
# 3. Reshape `raw_batch` into a 2D tensor named `mlp_ready_batch` without altering the first index.
#    (Hint: your target dimension shape should be (8, 3 * 64 * 64) or use -1: `.reshape(8, -1)`).
# 4. Print the final shape and verify it is exactly (8, 12288).
# ==============================================================================================

# Write your solution in a new cell below this one

# %%
# ==============================================================================================
# QUESTION 9: Grayscale Batch Dimensional Expansion
# ----------------------------------------------------------------------------------------------
# Task: Fix a common framework error where grayscale batches lose their channel dimension.
#
# Requirements:
# 1. Suppose you load a grayscale batch array with a missing channel axis:
#    incomplete_grayscale_batch = np.random.rand(16, 28, 28)  # Shape: (N, H, W)
# 2. Deep learning layers strictly expect a 4D setup: (N, C, H, W). For grayscale, C must be 1.
# 3. Use `.reshape()` or `np.expand_dims()` to transform the shape into explicitly (16, 1, 28, 28).
# 4. Print the modified shape to confirm the channel dimension was added successfully.
# ==============================================================================================

# Write your solution in a new cell below this one

# %%
# ==============================================================================================
# QUESTION 10: Dynamic Batch Splitting (The Mini-Batch Loop)
# ----------------------------------------------------------------------------------------------
# Task: Simulate a training step loop by slicing a large dataset batch into smaller sub-batches.
#
# Requirements:
# 1. Create a large data tensor named `dataset_matrix` containing 10 samples, where each sample 
#    is a flattened vector of 50 features. (Initial shape: (10, 50)).
# 2. Set a variable `mini_batch_size = 2`.
# 3. Use a standard `for` loop with a step configuration (hint: range(0, total_samples, step_size)) 
#    to slide through `dataset_matrix`.
# 4. Inside the loop, slice out subsets of 2 rows at a time and print the shape of each sliced 
#    mini-batch to verify it splits into exactly (2, 50).
# ==============================================================================================

# Write your solution in a new cell below this one
