# %% [markdown]
# ## Binary Image Classifier: Dog vs Cat

# %%
import numpy as np
x = np.random.rand(5)
y_true = [0, 1, 1, 0, 0]
print(x)
# Out:
# [0.95722154 0.1395252  0.67570611 0.25450477 0.32427536]

# %%
# Initializing random parameters of Model

# Forward pass
m = 0.9
c = -0.2
y_preds = m * x + c
y_preds > 0.5 # [1, 0, 0, 0, 0]
# Out:
# array([ True, False, False, False, False])

# %% [markdown]
# ## Train the Model

# %%
# Backpropagation or backward pass --> Gradient Descent

# %%
# False --> 0 --> Cat
# True --> 1 --> Dog
